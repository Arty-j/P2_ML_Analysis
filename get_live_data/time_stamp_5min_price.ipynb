# %% [markdown]
# Importing Exchange data from CoinGecko to create giant df

# %%
import datetime
import time
import json
import requests
import pandas as pd
from pandas import json_normalize

# %%
coin_id = ['bitcoin', 'ethereum', 'tether', 'usd-coin', 'binancecoin']
exchange = ['binance', 'coinbase', 'okx', 'huobi']
 
def create_exchange_df(exchange, coin_id):
    for x in exchange:
        exchange_data = get_coin_data(x, coin_id)
        exchange_df = pd.DataFrame(exchange_data)
    return exchange_df


def get_coin_data (exchange, coin_id):
    exchange_df = pd.DataFrame()
    for coin in coin_id:
        url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin}"
        response = requests.get(url)
        data = response.json()
        df = json_normalize(data['tickers'][0])
        exchange_df = exchange_df.append(df, ignore_index=True)
        print(df)
       
        
        
#     df1["timestamp"] = pd.to_datetime(df1["timestamp"], infer_datetime_format =True, utc = True)
#     df1 = df1[['base',
#           'target', 'last', 'volume', 'bid_ask_spread_percentage',
#           'timestamp', 'market.name', 'market.identifier', 'market.has_trading_incentive',
#           'converted_last.usd', 'converted_volume.usd']]
#     df1 = df1.reset_index()
#     df1 = df1.set_index('timestamp')
#     pd.options.display.float_format = '{:.2f}'.format
#     print (df)
#     return df
create_exchange_df(exchange, coin_id)
# Out:
#   base target      last        volume trust_score  bid_ask_spread_percentage  \
# 0  BTC   USDT  16763.22  122065.92812       green                   0.011431
#
#                    timestamp             last_traded_at  \
# 0  2022-12-18T04:18:51+00:00  2022-12-18T04:18:51+00:00
#
#                last_fetch_at  is_anomaly  ...  target_coin_id market.name  \
# 0  2022-12-18T04:18:51+00:00       False  ...          tether     Binance
#
#   market.identifier market.has_trading_incentive converted_last.btc  \
# 0           binance                        False           0.999611
#
#   converted_last.eth converted_last.usd  converted_volume.btc  \
# 0          14.052806           16762.87                122018
#
#    converted_volume.eth  converted_volume.usd
# 0               1715369            2046175132
#
# [1 rows x 24 columns]
#   base target     last        volume trust_score  bid_ask_spread_percentage  \
# 0  ETH   USDT  1193.81  269402.74436       green                   0.010838
# ...

# %%
coin_id = ['bitcoin', 'ethereum', 'tether', 'usd-coin', 'binancecoin']
exchange = ['binance', 'coinbase', 'okx', 'huobi']
 
def create_exchange_df(exchange, coin_id):
    for x in exchange:
        exchange_data = get_coin_data(x, coin_id)
        exchange_df = pd.DataFrame(exchange_data)
    return exchange_df


def get_coin_data (exchange, coin_id):
    for coin in coin_id:
        url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin}"
        response = requests.get(url)
        data = response.json()
        timestamp_list = []
        price_list = []
        volume_list = []
        price_spread = []
        for row in data['tickers'] :
            # dt = datetime.datetime.fromtimestamp(row[0]/ 1000)
            # formatted_time = dt.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]
            # timestamp_list.append(formatted_time)
            # price_list.append(row[1])
            
    raw_data = {'timestamp': timestamp_list, 'price' : price_list}
    df = pd.DataFrame(raw_data, columns=['timestamp','price'])
    df = df.reset_index()
    df = df.set_index('timestamp')
    #pd.options.display.float_format = '{:.2f}'.format
        
    # return df

# %%
url = f"https://api.coingecko.com/api/v3/exchanges/{exchange}/tickers?coin_ids={coin_id}
{
  "name": "Binance",
  "tickers": 
    {
      "base": "BTC",
      "target": "USDT",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 17767.82,
      "volume": 280686.47988155874,
      "converted_last": {
        "btc": 0.99935262,
        "eth": 13.463059,
        "usd": 17765.22
      },
      "converted_volume": {
        "btc": 280505,
        "eth": 3778899,
        "usd": 4986456005
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.013377,
      "timestamp": "2022-12-13T23:56:47+00:00",
      "last_traded_at": "2022-12-13T23:56:47+00:00",
      "last_fetch_at": "2022-12-13T23:56:47+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_USDT?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin",
      "target_coin_id": "tether"
    },
    {
      "base": "BTC",
      "target": "BUSD",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 17802.45,
      "volume": 181567.77417227748,
      "converted_last": {
        "btc": 0.99998146,
        "eth": 13.464982,
        "usd": 17790.67
      },
      "converted_volume": {
        "btc": 181564,
        "eth": 2444807,
        "usd": 3230212339
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.013595,
      "timestamp": "2022-12-13T23:38:52+00:00",
      "last_traded_at": "2022-12-13T23:38:52+00:00",
      "last_fetch_at": "2022-12-13T23:38:52+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_BUSD?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin",
      "target_coin_id": "binance-usd"
    },
    {
      "base": "BTC",
      "target": "EUR",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 16731.27,
      "volume": 4220.534199550148,
      "converted_last": {
        "btc": 0.99944375,
        "eth": 13.454386,
        "usd": 17781.71
      },
      "converted_volume": {
        "btc": 4218,
        "eth": 56785,
        "usd": 75048301
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.04278,
      "timestamp": "2022-12-13T23:43:50+00:00",
      "last_traded_at": "2022-12-13T23:43:50+00:00",
      "last_fetch_at": "2022-12-13T23:43:50+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_EUR?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "TRY",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 335650,
      "volume": 1336.3243102249962,
      "converted_last": {
        "btc": 1.013437,
        "eth": 13.642764,
        "usd": 18030.67
      },
      "converted_volume": {
        "btc": 1354,
        "eth": 18231,
        "usd": 24094827
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.017746,
      "timestamp": "2022-12-13T23:43:50+00:00",
      "last_traded_at": "2022-12-13T23:43:50+00:00",
      "last_fetch_at": "2022-12-13T23:43:50+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_TRY?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "GBP",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 14223.84,
      "volume": 1287.3101204584275,
      "converted_last": {
        "btc": 0.98875535,
        "eth": 13.320295,
        "usd": 17576.83
      },
      "converted_volume": {
        "btc": 1273,
        "eth": 17147,
        "usd": 22626833
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.019652,
      "timestamp": "2022-12-13T23:56:51+00:00",
      "last_traded_at": "2022-12-13T23:56:51+00:00",
      "last_fetch_at": "2022-12-13T23:56:51+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_GBP?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "AUD",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 25908.99,
      "volume": 1214.8401131709186,
      "converted_last": {
        "btc": 0.99722042,
        "eth": 13.423446,
        "usd": 17740.54
      },
      "converted_volume": {
        "btc": 1211,
        "eth": 16307,
        "usd": 21551916
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.025781,
      "timestamp": "2022-12-13T23:42:01+00:00",
      "last_traded_at": "2022-12-13T23:42:01+00:00",
      "last_fetch_at": "2022-12-13T23:42:01+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_AUD?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "BRL",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 93259,
      "volume": 658.017961831137,
      "converted_last": {
        "btc": 0.99013207,
        "eth": 13.332356,
        "usd": 17614.98
      },
      "converted_volume": {
        "btc": 651.525,
        "eth": 8773,
        "usd": 11590975
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.027868,
      "timestamp": "2022-12-13T23:37:18+00:00",
      "last_traded_at": "2022-12-13T23:37:18+00:00",
      "last_fetch_at": "2022-12-13T23:37:18+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_BRL?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "DAI",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 17788.99,
      "volume": 78.96450141277273,
      "converted_last": {
        "btc": 0.9995508,
        "eth": 13.456727,
        "usd": 17783.47
      },
      "converted_volume": {
        "btc": 78.929,
        "eth": 1063,
        "usd": 1404263
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.029733,
      "timestamp": "2022-12-13T23:44:41+00:00",
      "last_traded_at": "2022-12-13T23:44:41+00:00",
      "last_fetch_at": "2022-12-13T23:44:41+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_DAI?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin",
      "target_coin_id": "dai"
    },
    {
      "base": "BTC",
      "target": "BIDR",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 277706847,
      "volume": 92.03021945047685,
      "converted_last": {
        "btc": 0.99953224,
        "eth": 13.45412,
        "usd": 17783.68
      },
      "converted_volume": {
        "btc": 91.987,
        "eth": 1238,
        "usd": 1636636
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.094849,
      "timestamp": "2022-12-13T23:41:58+00:00",
      "last_traded_at": "2022-12-13T23:41:58+00:00",
      "last_fetch_at": "2022-12-13T23:41:58+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_BIDR?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin",
      "target_coin_id": "binanceidr"
    },
    {
      "base": "BTC",
      "target": "PLN",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 78688,
      "volume": 35.365258324268,
      "converted_last": {
        "btc": 1.002194,
        "eth": 13.505714,
        "usd": 17813.81
      },
      "converted_volume": {
        "btc": 35.442855,
        "eth": 477.633,
        "usd": 629990
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.160128,
      "timestamp": "2022-12-13T23:57:25+00:00",
      "last_traded_at": "2022-12-13T23:57:25+00:00",
      "last_fetch_at": "2022-12-13T23:57:25+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_PLN?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "ZAR",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 310200,
      "volume": 18.295624082817536,
      "converted_last": {
        "btc": 1.010317,
        "eth": 13.600998,
        "usd": 17975.37
      },
      "converted_volume": {
        "btc": 18.484388,
        "eth": 248.839,
        "usd": 328871
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.143794,
      "timestamp": "2022-12-13T23:37:28+00:00",
      "last_traded_at": "2022-12-13T23:37:28+00:00",
      "last_fetch_at": "2022-12-13T23:40:21+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_ZAR?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "RUB",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 1128698,
      "volume": 21.362843015908595,
      "converted_last": {
        "btc": 1.003558,
        "eth": 13.509773,
        "usd": 17854.91
      },
      "converted_volume": {
        "btc": 21.438855,
        "eth": 288.607,
        "usd": 381432
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.106025,
      "timestamp": "2022-12-13T23:43:15+00:00",
      "last_traded_at": "2022-12-13T23:43:15+00:00",
      "last_fetch_at": "2022-12-13T23:43:15+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_RUB?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    },
    {
      "base": "BTC",
      "target": "UAH",
      "market": {
        "name": "Binance",
        "identifier": "binance",
        "has_trading_incentive": false
      },
      "last": 699636,
      "volume": 13.954293136688221,
      "converted_last": {
        "btc": 1.071038,
        "eth": 14.428795,
        "usd": 19039.56
      },
      "converted_volume": {
        "btc": 14.945585,
        "eth": 201.344,
        "usd": 265684
      },
      "trust_score": "green",
      "bid_ask_spread_percentage": 0.198049,
      "timestamp": "2022-12-13T23:54:14+00:00",
      "last_traded_at": "2022-12-13T23:54:14+00:00",
      "last_fetch_at": "2022-12-13T23:56:51+00:00",
      "is_anomaly": false,
      "is_stale": false,
      "trade_url": "https://www.binance.com/en/trade/BTC_UAH?ref=37754157",
      "token_info_url": null,
      "coin_id": "bitcoin"
    }
  ]
}
Response headers
 cache-control: public,max-age=120 
 content-type: application/json; charset=utf-8 
 expires: Wed,14 Dec 2022 00:01:27 GMT 
 per-page:
