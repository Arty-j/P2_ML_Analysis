# %%
import datetime
import time
import json
import requests
import pandas as pd
from pandas import json_normalize

# %%
url = f"https://api.coingecko.com/api/v3/exchanges/binance/tickers?coin_ids=usd_coin"
response = requests.get(url)
data = response.json()
df = json_normalize(data['tickers'][0])
df.head()
# Out:
#    base target    last        volume trust_score  bid_ask_spread_percentage  \
# 0  BUSD   USDT  0.9999  6.346104e+08       green                       0.02
#
#                    timestamp             last_traded_at  \
# 0  2022-12-18T04:16:15+00:00  2022-12-18T04:16:15+00:00
#
#                last_fetch_at  is_anomaly  ...  target_coin_id market.name  \
# 0  2022-12-18T04:16:15+00:00       False  ...          tether     Binance
#
#   market.identifier market.has_trading_incentive converted_last.btc  \
# 0           binance                        False            0.00006
#
#   converted_last.eth converted_last.usd  converted_volume.btc  \
# 0            0.00084           0.999767                 37898
#
#    converted_volume.eth  converted_volume.usd
# 0                532921             634462642
#
# [1 rows x 24 columns]

# %%
df["timestamp"] = pd.to_datetime(
    df["timestamp"],
    infer_datetime_format =True,
    utc = True
)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 24 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   base                          1 non-null      object
#  1   target                        1 non-null      object
#  2   last                          1 non-null      float64
#  3   volume                        1 non-null      float64
#  4   trust_score                   1 non-null      object
#  5   bid_ask_spread_percentage     1 non-null      float64
#  6   timestamp                     1 non-null      datetime64[ns, UTC]
#  7   last_traded_at                1 non-null      object
#  8   last_fetch_at                 1 non-null      object
#  9   is_anomaly                    1 non-null      bool
#  10  is_stale                      1 non-null      bool
#  11  trade_url                     1 non-null      object
#  12  token_info_url                0 non-null      object
#  13  coin_id                       1 non-null      object
#  14  target_coin_id                1 non-null      object
#  15  market.name                   1 non-null      object
#  16  market.identifier             1 non-null      object
#  17  market.has_trading_incentive  1 non-null      bool
#  18  converted_last.btc            1 non-null      float64
#  19  converted_last.eth            1 non-null      float64
#  20  converted_last.usd            1 non-null      float64
#  21  converted_volume.btc          1 non-null      int64
#  22  converted_volume.eth          1 non-null      int64
#  23  converted_volume.usd          1 non-null      int64
# dtypes: bool(3), datetime64[ns, UTC](1), float64(6), int64(3), object(11)
# memory usage: 299.0+ bytes

# %%
df1 = df[['base',
          'target', 'last', 'volume', 'bid_ask_spread_percentage',
          'timestamp', 'market.name', 'market.identifier', 'market.has_trading_incentive',
          'converted_last.usd', 'converted_volume.usd']]
df1
# Out:
#    base target    last        volume  bid_ask_spread_percentage  \
# 0  BUSD   USDT  0.9999  6.346104e+08                       0.02
#
#                   timestamp market.name market.identifier  \
# 0 2022-12-18 04:16:15+00:00     Binance           binance
#
#    market.has_trading_incentive  converted_last.usd  converted_volume.usd
# 0                         False            0.999767             634462642
